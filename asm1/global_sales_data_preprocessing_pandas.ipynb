# %% [raw]
# Data preprocessing for the global sales data in the udemy course below<br>
# https://www.udemy.com/course/the-complete-power-bi-practical-course

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../input_data/udemy_ms_powerbi/factInternetSales.csv')

# Display the first few rows
df.head()
# Out:
#    ProductKey   OrderDate     DueDate   ShipDate  CustomerKey  PromotionKey  \
# 0         310  29/12/2010  10/01/2011  5/01/2011        21768             1
# 1         346  29/12/2010  10/01/2011  5/01/2011        28389             1
# 2         346  29/12/2010  10/01/2011  5/01/2011        25863             1
# 3         336  29/12/2010  10/01/2011  5/01/2011        14501             1
# 4         346  29/12/2010  10/01/2011  5/01/2011        11003             1
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  RevisionNumber  \
# 0                  6          SO43697                     1               1
# 1                  7          SO43698                     1               1
# 2                  1          SO43699                     1               1
# 3                  4          SO43700                     1               1
# 4                  9          SO43701                     1               1
#
#    ...  UnitPriceDiscountPct  DiscountAmount  ProductStandardCost  \
# 0  ...                     0               0            2171.2942
# 1  ...                     0               0            1912.1544
# 2  ...                     0               0            1912.1544
# 3  ...                     0               0             413.1463
# 4  ...                     0               0            1912.1544
#
#    TotalProductCost  29        6  98       19  36        100
# 0         2171.2942 NaN      NaN NaN  3578.27 NaN        NaN
# 1         1912.1544 NaN      NaN NaN      NaN NaN        NaN
# 2         1912.1544 NaN      NaN NaN      NaN NaN  3399.9900
# 3          413.1463 NaN      NaN NaN      NaN NaN   699.0982
# 4         1912.1544 NaN  3399.99 NaN      NaN NaN        NaN
#
# [5 rows x 23 columns]

# %%
# Unpivot to create the 2 columns: Currency Key & Sales Amount
df_unpivoted = pd.melt(
    df,
    id_vars=["ProductKey",
             "OrderDate",
             "DueDate",
             "ShipDate",
             "CustomerKey",
             "PromotionKey",
             "SalesTerritoryKey",
             "SalesOrderNumber",
             "SalesOrderLineNumber",
             "RevisionNumber",
             "OrderQuantity",
             "UnitPrice",
             "ExtendedAmount",
             "UnitPriceDiscountPct",
             "DiscountAmount",
             "ProductStandardCost",
             "TotalProductCost"],  # Columns to keep fixed
    var_name="Currency Key",  # Name for the unpivoted variable column
    value_name="Sales Amount"  # Name for the unpivoted value column
)
# Change 'Currency Key' column from 'object' to 'int64'
df_unpivoted["Currency Key"] = df_unpivoted["Currency Key"].astype("int64")

df_unpivoted.tail()
# Out:
#         ProductKey   OrderDate    DueDate   ShipDate  CustomerKey  \
# 362383         485  28/01/2014  9/02/2014  4/02/2014        15868
# 362384         225  28/01/2014  9/02/2014  4/02/2014        15868
# 362385         485  28/01/2014  9/02/2014  4/02/2014        18759
# 362386         486  28/01/2014  9/02/2014  4/02/2014        18759
# 362387         225  28/01/2014  9/02/2014  4/02/2014        18759
#
#         PromotionKey  SalesTerritoryKey SalesOrderNumber  \
# 362383             1                  6          SO75122
# 362384             1                  6          SO75122
# 362385             1                  6          SO75123
# 362386             1                  6          SO75123
# 362387             1                  6          SO75123
#
#         SalesOrderLineNumber  RevisionNumber  OrderQuantity  UnitPrice  \
# 362383                     1               1              1      21.98
# 362384                     2               1              1       8.99
# 362385                     1               1              1      21.98
# 362386                     2               1              1     159.00
# 362387                     3               1              1       8.99
#
#         ExtendedAmount  UnitPriceDiscountPct  DiscountAmount  \
# 362383           21.98                     0               0
# 362384            8.99                     0               0
# 362385           21.98                     0               0
# 362386          159.00                     0               0
# 362387            8.99                     0               0
#
#         ProductStandardCost  TotalProductCost  Currency Key  Sales Amount
# 362383               8.2205            8.2205           100         21.98
# 362384               6.9223            6.9223           100          8.99
# 362385               8.2205            8.2205           100         21.98
# 362386              59.4660           59.4660           100        159.00
# 362387               6.9223            6.9223           100          8.99

# %%
# Just get the records having valid sales amount
df_fact_internet_sales = df_unpivoted[df_unpivoted["Sales Amount"].notnull()]
len(df_fact_internet_sales)
# Out:
# 60339

# %%
# Load dim currency table into a dataframe
df_dim_currency = pd.read_csv('../input_data/udemy_ms_powerbi/dimCurrency.csv')
df_dim_currency
# Out:
#    CurrencyKey CurrencyAlternateKey          CurrencyName  Exchange Rate
# 0            6                  AUD     Australian Dollar           1.62
# 1           19                  CAD       Canadian Dollar           1.50
# 2           29                  DEM         Deutsche Mark           1.00
# 3           36                  EUR                  EURO           1.00
# 4           98                  GBP  United Kingdom Pound           0.83
# 5          100                  USD             US Dollar           1.08

# %%
# Merge fact internet sales & dim currency
df_result = pd.merge(df_fact_internet_sales, df_dim_currency, left_on="Currency Key", right_on="CurrencyKey", how="left")

df_result.tail()
# Out:
#        ProductKey   OrderDate    DueDate   ShipDate  CustomerKey  \
# 60334         485  28/01/2014  9/02/2014  4/02/2014        15868
# 60335         225  28/01/2014  9/02/2014  4/02/2014        15868
# 60336         485  28/01/2014  9/02/2014  4/02/2014        18759
# 60337         486  28/01/2014  9/02/2014  4/02/2014        18759
# 60338         225  28/01/2014  9/02/2014  4/02/2014        18759
#
#        PromotionKey  SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  \
# 60334             1                  6          SO75122                     1
# 60335             1                  6          SO75122                     2
# 60336             1                  6          SO75123                     1
# 60337             1                  6          SO75123                     2
# 60338             1                  6          SO75123                     3
#
#        RevisionNumber  ...  UnitPriceDiscountPct  DiscountAmount  \
# 60334               1  ...                     0               0
# 60335               1  ...                     0               0
# 60336               1  ...                     0               0
# 60337               1  ...                     0               0
# 60338               1  ...                     0               0
#
#        ProductStandardCost  TotalProductCost  Currency Key  Sales Amount  \
# 60334               8.2205            8.2205           100         21.98
# 60335               6.9223            6.9223           100          8.99
# 60336               8.2205            8.2205           100         21.98
# 60337              59.4660           59.4660           100        159.00
# 60338               6.9223            6.9223           100          8.99
#
#        CurrencyKey  CurrencyAlternateKey  CurrencyName  Exchange Rate
# 60334          100                   USD     US Dollar           1.08
# 60335          100                   USD     US Dollar           1.08
# 60336          100                   USD     US Dollar           1.08
# 60337          100                   USD     US Dollar           1.08
# 60338          100                   USD     US Dollar           1.08
#
# [5 rows x 23 columns]

# %%
# Drop 3 redundant columns & rename 1 column
df_result = df_result.drop(columns=["Currency Key", "CurrencyKey", "CurrencyName"]).rename(columns={"CurrencyAlternateKey": "Currency Code"})
df_result.tail()
# Out:
#        ProductKey   OrderDate    DueDate   ShipDate  CustomerKey  \
# 60334         485  28/01/2014  9/02/2014  4/02/2014        15868
# 60335         225  28/01/2014  9/02/2014  4/02/2014        15868
# 60336         485  28/01/2014  9/02/2014  4/02/2014        18759
# 60337         486  28/01/2014  9/02/2014  4/02/2014        18759
# 60338         225  28/01/2014  9/02/2014  4/02/2014        18759
#
#        PromotionKey  SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  \
# 60334             1                  6          SO75122                     1
# 60335             1                  6          SO75122                     2
# 60336             1                  6          SO75123                     1
# 60337             1                  6          SO75123                     2
# 60338             1                  6          SO75123                     3
#
#        RevisionNumber  OrderQuantity  UnitPrice  ExtendedAmount  \
# 60334               1              1      21.98           21.98
# 60335               1              1       8.99            8.99
# 60336               1              1      21.98           21.98
# 60337               1              1     159.00          159.00
# 60338               1              1       8.99            8.99
#
#        UnitPriceDiscountPct  DiscountAmount  ProductStandardCost  \
# 60334                     0               0               8.2205
# 60335                     0               0               6.9223
# 60336                     0               0               8.2205
# 60337                     0               0              59.4660
# 60338                     0               0               6.9223
#
#        TotalProductCost  Sales Amount Currency Code  Exchange Rate
# 60334            8.2205         21.98           USD           1.08
# 60335            6.9223          8.99           USD           1.08
# 60336            8.2205         21.98           USD           1.08
# 60337           59.4660        159.00           USD           1.08
# 60338            6.9223          8.99           USD           1.08

# %%
df_result["Sales Amount EUR"] = df_result["Sales Amount"] / df_result["Exchange Rate"]
df_result.head()
# Out:
#    ProductKey   OrderDate     DueDate    ShipDate  CustomerKey  PromotionKey  \
# 0         311   1/01/2011  13/01/2011   8/01/2011        13513             1
# 1         311   3/01/2011  15/01/2011  10/01/2011        13264             1
# 2         311   5/01/2011  17/01/2011  12/01/2011        13258             1
# 3         311   8/01/2011  20/01/2011  15/01/2011        13261             1
# 4         311  11/01/2011  23/01/2011  18/01/2011        13265             1
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  RevisionNumber  \
# 0                  8          SO43712                     1               1
# 1                  8          SO43720                     1               1
# 2                  8          SO43725                     1               1
# 3                  8          SO43737                     1               1
# 4                  8          SO43752                     1               1
#
#    ...  UnitPrice  ExtendedAmount  UnitPriceDiscountPct  DiscountAmount  \
# 0  ...    3578.27         3578.27                     0               0
# 1  ...    3578.27         3578.27                     0               0
# 2  ...    3578.27         3578.27                     0               0
# 3  ...    3578.27         3578.27                     0               0
# 4  ...    3578.27         3578.27                     0               0
#
#    ProductStandardCost  TotalProductCost  Sales Amount  Currency Code  \
# 0            2171.2942         2171.2942       3578.27            DEM
# 1            2171.2942         2171.2942       3578.27            DEM
# 2            2171.2942         2171.2942       3578.27            DEM
# 3            2171.2942         2171.2942       3578.27            DEM
# 4            2171.2942         2171.2942       3578.27            DEM
#
#   Exchange Rate  Sales Amount EUR
# 0           1.0           3578.27
# 1           1.0           3578.27
# 2           1.0           3578.27
# 3           1.0           3578.27
# 4           1.0           3578.27
#
# [5 rows x 21 columns]

# %%
df_result = df_result.drop(columns=["Sales Amount", "Exchange Rate"])
df_result.head()
df_result.to_csv('../input_data/udemy_ms_powerbi/expected_factInternetSales.csv', index=False)
